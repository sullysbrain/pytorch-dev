# %%
import polars as pl

# %%
d = {"a": [1,2], "b": [3,4]}

# %%
df = pl.DataFrame(d)

# %%
print(df)
# Out:
# shape: (2, 2)
# ┌─────┬─────┐
# │ a   ┆ b   │
# │ --- ┆ --- │
# │ i64 ┆ i64 │
# ╞═════╪═════╡
# │ 1   ┆ 3   │
# │ 2   ┆ 4   │
# └─────┴─────┘
