# %%
import polars as pl

# %%
d = {"a": [1,22,3], "b": [4,5,6]}

# %%
df = pl.DataFrame(d)

# %%
print(df)
# Out:
# shape: (3, 2)
# ┌─────┬─────┐
# │ a   ┆ b   │
# │ --- ┆ --- │
# │ i64 ┆ i64 │
# ╞═════╪═════╡
# │ 1   ┆ 4   │
# │ 22  ┆ 5   │
# │ 3   ┆ 6   │
# └─────┴─────┘
