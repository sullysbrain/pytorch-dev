# %%
import polars as pl

# %%
d = {"a": [1,2,3], "b":[5,6,7]}

# %%
df = pl.DataFrame(d)

# %%
print(df)
# Out:
# shape: (3, 2)
# ┌─────┬─────┐
# │ a   ┆ b   │
# │ --- ┆ --- │
# │ i64 ┆ i64 │
# ╞═════╪═════╡
# │ 1   ┆ 5   │
# │ 2   ┆ 6   │
# │ 3   ┆ 7   │
# └─────┴─────┘
